# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#  Used to ensure matplotlib output is PNG
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png')
# %matplotlib inline

# %%
import oscovida.plots._matplotlib as plots

# %%
region = pd.read_csv(
    "../test_data/20200901_level_1.csv",
    index_col='date',
    parse_dates=['date'],
)

# %%
data = region[region.id=='DEU']

# %%
# NBVAL_IGNORE_OUTPUT
#  This cell has its output ignored
#  matplotlib raises some warning on first plot
plt.figure(figsize=(10,5))
plots.plot_totals(data.confirmed)
plots.plot_totals(data.deaths)
plt.show()

# %%
plt.figure(figsize=(10,5))
plots.plot_totals(data.confirmed)
plots.plot_totals(data.deaths)
plt.show()

# %%
plt.figure(figsize=(10,5))
plots.plot_totals(data.confirmed, label_prepend="DEU")
plots.plot_totals(data.deaths, label_prepend="DEU")
plt.show()

# %%
plt.figure(figsize=(10,5))
plots.plot_daily(data.confirmed)
plots.plot_daily(data.deaths)
plt.show()

# %%
plt.figure(figsize=(10,5))
plots.plot_daily(data.confirmed, label_prepend="DEU")
plots.plot_daily(data.deaths, label_prepend="DEU")
plt.show()

# %%
plt.figure(figsize=(10,5))
plots.plot_r_number(data.confirmed)
plots.plot_r_number(data.deaths)
plt.show()

# %%
plt.figure(figsize=(10,5))
plots.plot_r_number(data.confirmed, label_prepend="DEU")
plots.plot_r_number(data.deaths, label_prepend="DEU")
plt.show()

# %%
plt.figure(figsize=(10,5))
plots.plot_growth_factor(data.confirmed)
plots.plot_growth_factor(data.deaths)
plt.show()

# %%
plt.figure(figsize=(10,5))
plots.plot_growth_factor(data.confirmed, label_prepend="DEU")
plots.plot_growth_factor(data.deaths, label_prepend="DEU")
plt.show()

# %%
plt.figure(figsize=(10,5))
plots.plot_doubling_time(data.confirmed)
plots.plot_doubling_time(data.deaths)
plt.show()

# %%
plt.figure(figsize=(10,5))
plots.plot_doubling_time(data.confirmed, label_prepend="DEU")
plots.plot_doubling_time(data.deaths, label_prepend="DEU")
plt.show()
